# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0517/python-basics/blob/master/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt 
from sklearn import metrics

# %%
fi=pd.read_csv("py.csv")
fi
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
fi.boxplot(by="Section",column="B.Tech_percentage")
fi
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
A section perform well as compared to B section according to th the box plot

# %%
si=pd.read_csv("Iris.csv")
si
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
x=si[["PetalLengthCm","PetalWidthCm"]].values
y=si[["SepalLengthCm"]].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
m=LinearRegression()
m.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X=m.predict(x_test)

# %%
y=pd.DataFrame({"actual":y_test.flatten(),"predicted":x.flatten()})
y
# Out:
#     actual  predicted
# 0      5.0   4.844585
# 1      5.0   5.789033
# 2      4.9   6.109597
# 3      5.1   4.948566
# 4      5.4   5.024069
# 5      7.7   7.167953
# 6      5.1   5.500604
# 7      5.5   5.963553
# 8      4.4   4.925052
# 9      7.2   6.713626
# 10     6.1   6.247018
# 11     7.2   6.860974
# 12     5.7   6.015544
# 13     6.1   5.963553
# 14     6.0   6.426502
# 15     5.0   4.821072
# 16     6.3   6.289081
# 17     6.3   6.242055
# 18     7.7   7.110999
# 19     4.9   5.685052
# 20     4.8   5.185004
# 21     5.9   6.237091
# 22     5.6   6.166551
# 23     5.0   4.915125
# 24     6.4   6.166551
# 25     4.3   4.797558
# 26     6.3   6.312595
# 27     6.2   6.119524
# 28     5.0   4.925052
# 29     6.3   6.653013
# 30     6.5   6.218541
# 31     4.9   5.005519
# 32     5.2   5.005519
# 33     6.5   6.388098
# 34     5.0   4.972079
# 35     6.2   6.237091
# 36     5.6   6.067534
# 37     5.1   4.920089

# %%
print("R2error:",metrics.r2_error(y_test,X))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-48e89f489607> in <module>()
# ----> 1 print("R2error:",metrics.r2_error(y_test,X))
#
# AttributeError: module 'sklearn.metrics' has no attribute 'r2_error'
